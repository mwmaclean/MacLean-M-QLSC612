# %% [markdown]
# # QLSC612 Assignement, BrainHack Summer School, May 2020

# %%
import pandas as pd
import numpy as np

# Load Data and read the CSV file
csvfile = ('/mnt/c/Users/michm/BrainHack2020/course-2020-assessments/practical/brainsize.csv')
data = pandas.read_csv(csvfile, sep=';', index_col=0)

#Check the first 5 rows of the data
data.head()
# Out:
#    Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 1  Female   133  132  124    118   64.5     816932
# 2    Male   140  150  124      .   72.5    1001121
# 3    Male   139  123  150    143   73.3    1038437
# 4    Male   133  129  128    172   68.8     965353
# 5  Female   137  132  134    147   65.0     951545

# %%
#Lets look at the type of data
print('What type is data ? : ', type(data))
print("It stores values in a numpy array:", type(data.values))
data.values[:5]
# Out:
# What type is data ? :  <class 'pandas.core.frame.DataFrame'>
# It stores values in a numpy array: <class 'numpy.ndarray'>
# array([['Female', 133, 132, 124, '118', '64.5', 816932],
#        ['Male', 140, 150, 124, '.', '72.5', 1001121],
#        ['Male', 139, 123, 150, '143', '73.3', 1038437],
#        ['Male', 133, 129, 128, '172', '68.8', 965353],
#        ['Female', 137, 132, 134, '147', '65.0', 951545]], dtype=object)

# %%
#Missing values, the weight is missing for the second individual, we need to specify the missing value.

data = pandas.read_csv(csvfile, sep=';', na_values=".")
data.head(3) #.dropna() #make sure the missing value now reads NaN
# Out:
#    Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0           1  Female   133  132  124   118.0    64.5     816932
# 1           2    Male   140  150  124     NaN    72.5    1001121
# 2           3    Male   139  123  150   143.0    73.3    1038437

# %%
#Manipulate the data
#Lets look at the shape and columns of the data
print('data.shape: ', data.shape)
print('data.columns: ',data.columns)

#print('\nFemale VIQ mean: ', data[data['Gender'] == 'Female']['VIQ'].mean())

#Lets look at the main stats of the data
data.describe()
# Out:
# data.shape:  (40, 8)
# data.columns:  Index(['Unnamed: 0', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height',
#        'MRI_Count'],
#       dtype='object')
#        Unnamed: 0        FSIQ         VIQ        PIQ      Weight     Height  \
# count   40.000000   40.000000   40.000000   40.00000   38.000000  39.000000
# mean    20.500000  113.450000  112.350000  111.02500  151.052632  68.525641
# std     11.690452   24.082071   23.616107   22.47105   23.478509   3.994649
# min      1.000000   77.000000   71.000000   72.00000  106.000000  62.000000
# 25%     10.750000   89.750000   90.000000   88.25000  135.250000  66.000000
# 50%     20.500000  116.500000  113.000000  115.00000  146.500000  68.000000
# 75%     30.250000  135.500000  129.750000  128.00000  172.000000  70.500000
# max     40.000000  144.000000  150.000000  150.00000  192.000000  77.000000
#
#           MRI_Count
# count  4.000000e+01
# mean   9.087550e+05
# std    7.228205e+04
# min    7.906190e+05
# 25%    8.559185e+05
# ...

# %%
#Change the gender column from a string (Female or Male) to an integer (1 or 2)

gender = {'Male': 1,'Female': 2} 
data.Gender = [gender[item] for item in data.Gender] 
print(data)
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0            1       2   133  132  124   118.0    64.5     816932
# 1            2       1   140  150  124     NaN    72.5    1001121
# 2            3       1   139  123  150   143.0    73.3    1038437
# 3            4       1   133  129  128   172.0    68.8     965353
# 4            5       2   137  132  134   147.0    65.0     951545
# 5            6       2    99   90  110   146.0    69.0     928799
# 6            7       2   138  136  131   138.0    64.5     991305
# 7            8       2    92   90   98   175.0    66.0     854258
# 8            9       1    89   93   84   134.0    66.3     904858
# 9           10       1   133  114  147   172.0    68.8     955466
# 10          11       2   132  129  124   118.0    64.5     833868
# 11          12       1   141  150  128   151.0    70.0    1079549
# 12          13       1   135  129  124   155.0    69.0     924059
# ...

# %%
#Lets plot the data with all possible variables
from pandas import plotting as pdplt
pdplt.scatter_matrix(data[['FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height', 'MRI_Count']]);

# %%
#Generate a new variable (named partY) of random noise
import numpy as np

ran_floats = np.random.rand (40,1)
partY = ran_floats

#randnums= np.random.random_sample(1,40) #this creates integers not floats
#partY = randnums
print(partY)
# Out:
# [[0.14008402]
#  [0.51832965]
#  [0.87737307]
#  [0.74076862]
#  [0.69701574]
#  [0.70248408]
#  [0.35949115]
#  [0.29359184]
#  [0.80936116]
#  [0.81011339]
#  [0.86707232]
#  [0.91324055]
#  [0.5113424 ]
#  [0.50151629]
#  [0.79829518]
#  [0.64996393]
#  [0.70196688]
#  [0.79579267]
#  [0.89000534]
#  [0.33799516]
#  [0.37558295]
#  [0.09398194]
#  [0.57828014]
#  [0.03594227]
#  [0.46559802]
#  [0.54264463]
#  [0.28654125]
#  [0.59083326]
#  [0.03050025]
#  [0.03734819]
#  [0.82260056]
#  [0.36019064]
#  [0.12706051]
#  [0.52224326]
#  [0.76999355]
#  [0.21582103]
#  [0.62289048]
#  [0.08534746]
#  [0.05168172]
#  [0.53135463]]

# %%
#Add variable partY to the existing brainsize.csv dataset.
df=pd.DataFrame(data)
df['partY']=partY
print(df)
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count     partY  \
# 0            1       2   133  132  124   118.0    64.5     816932  0.140084
# 1            2       1   140  150  124     NaN    72.5    1001121  0.518330
# 2            3       1   139  123  150   143.0    73.3    1038437  0.877373
# 3            4       1   133  129  128   172.0    68.8     965353  0.740769
# 4            5       2   137  132  134   147.0    65.0     951545  0.697016
# 5            6       2    99   90  110   146.0    69.0     928799  0.702484
# 6            7       2   138  136  131   138.0    64.5     991305  0.359491
# 7            8       2    92   90   98   175.0    66.0     854258  0.293592
# 8            9       1    89   93   84   134.0    66.3     904858  0.809361
# 9           10       1   133  114  147   172.0    68.8     955466  0.810113
# 10          11       2   132  129  124   118.0    64.5     833868  0.867072
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0    Gender        FSIQ         VIQ        PIQ      Weight  \
# count   40.000000  40.00000   40.000000   40.000000   40.00000   38.000000
# mean    20.500000   1.50000  113.450000  112.350000  111.02500  151.052632
# std     11.690452   0.50637   24.082071   23.616107   22.47105   23.478509
# min      1.000000   1.00000   77.000000   71.000000   72.00000  106.000000
# 25%     10.750000   1.00000   89.750000   90.000000   88.25000  135.250000
# 50%     20.500000   1.50000  116.500000  113.000000  115.00000  146.500000
# 75%     30.250000   2.00000  135.500000  129.750000  128.00000  172.000000
# max     40.000000   2.00000  144.000000  150.000000  150.00000  192.000000
#
#           Height     MRI_Count      partY     partY2
# count  39.000000  4.000000e+01  40.000000  40.000000
# mean   68.525641  9.087550e+05   0.501556  53.325000
# std     3.994649  7.228205e+04   0.281338  29.788474
# min    62.000000  7.906190e+05   0.030500   1.000000
# ...

# %%
#Generate a second new  variable (named partY2) of random noise 
import numpy as np
randnums= np.random.randint(1.0,101.0,40)
partY2 = randnums
print(partY2)
# Out:
# [55 75 56 17 38 24 69 98 70 86 11 16 97 73 59 70 80 93  3 20 59 36 19 90
#  67 19 20 96 71 52 33 40 39 82  1 11 92 57 89 50]

# %%
#Add variable partY to the existing brainsize.csv dataset.
df=pd.DataFrame(data)
df['partY2']=partY2
print(df)
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count  partY  \
# 0            1       2   133  132  124   118.0    64.5     816932      9
# 1            2       1   140  150  124     NaN    72.5    1001121     62
# 2            3       1   139  123  150   143.0    73.3    1038437     37
# 3            4       1   133  129  128   172.0    68.8     965353     97
# 4            5       2   137  132  134   147.0    65.0     951545     51
# 5            6       2    99   90  110   146.0    69.0     928799     44
# 6            7       2   138  136  131   138.0    64.5     991305     24
# 7            8       2    92   90   98   175.0    66.0     854258     79
# 8            9       1    89   93   84   134.0    66.3     904858     59
# 9           10       1   133  114  147   172.0    68.8     955466     32
# 10          11       2   132  129  124   118.0    64.5     833868     96
# 11          12       1   141  150  128   151.0    70.0    1079549     88
# ...

# %%
#We first add scipy.stats for simple statistical tests
from scipy import stats
from scipy import stats as sst

# %%
#Lets perform t-tests with all variables
stats.ttest_1samp(data['partY'], 0)
# Out:
# Ttest_1sampResult(statistic=11.275096808967474, pvalue=7.685379638485067e-14)

# %%
#Import matplotlib and seaborn library to make nice looking plots for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
